# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
speeddating = pd.read_csv('speeddating.csv', low_memory=False)
speeddating
# Out:
#       Unnamed: 0     genero  idade  idade_parceiro  \
# 0              0  b'female'   21.0            27.0
# 1              1  b'female'   21.0            22.0
# 2              2  b'female'   21.0            22.0
# 3              3  b'female'   21.0            23.0
# 4              4  b'female'   21.0            24.0
# ...          ...        ...    ...             ...
# 8373        8373    b'male'   25.0            26.0
# 8374        8374    b'male'   25.0            24.0
# 8375        8375    b'male'   25.0            29.0
# 8376        8376    b'male'   25.0            22.0
# 8377        8377    b'male'   25.0            22.0
#
#                                           raa  \
# 0     b'Asian/Pacific Islander/Asian-American'
# 1     b'Asian/Pacific Islander/Asian-American'
# 2     b'Asian/Pacific Islander/Asian-American'
# 3     b'Asian/Pacific Islander/Asian-American'
# 4     b'Asian/Pacific Islander/Asian-American'
# ...                                        ...
# ...

# %%
speeddating = pd.read_csv('speeddating.csv', low_memory=False, index_col=[0])
speeddating
# Out:
#          genero  idade  idade_parceiro  \
# 0     b'female'   21.0            27.0
# 1     b'female'   21.0            22.0
# 2     b'female'   21.0            22.0
# 3     b'female'   21.0            23.0
# 4     b'female'   21.0            24.0
# ...         ...    ...             ...
# 8373    b'male'   25.0            26.0
# 8374    b'male'   25.0            24.0
# 8375    b'male'   25.0            29.0
# 8376    b'male'   25.0            22.0
# 8377    b'male'   25.0            22.0
#
#                                           raa  \
# 0     b'Asian/Pacific Islander/Asian-American'
# 1     b'Asian/Pacific Islander/Asian-American'
# 2     b'Asian/Pacific Islander/Asian-American'
# 3     b'Asian/Pacific Islander/Asian-American'
# 4     b'Asian/Pacific Islander/Asian-American'
# ...                                        ...
# 8373            b'European/Caucasian-American'
# 8374            b'European/Caucasian-American'
# 8375            b'European/Caucasian-American'
# ...

# %%
speeddating.head()
# Out:
#       genero  idade  idade_parceiro                                      raa  \
# 0  b'female'   21.0            27.0  b'Asian/Pacific Islander/Asian-American'
# 1  b'female'   21.0            22.0  b'Asian/Pacific Islander/Asian-American'
# 2  b'female'   21.0            22.0  b'Asian/Pacific Islander/Asian-American'
# 3  b'female'   21.0            23.0  b'Asian/Pacific Islander/Asian-American'
# 4  b'female'   21.0            24.0  b'Asian/Pacific Islander/Asian-American'
#
#                               raa_parceiro Mesma raa?  \
# 0            b'European/Caucasian-American'        b'0'
# 1            b'European/Caucasian-American'        b'0'
# 2  b'Asian/Pacific Islander/Asian-American'        b'1'
# 3            b'European/Caucasian-American'        b'0'
# 4               b'Latino/Hispanic American'        b'0'
#
#    importancia_mesma_raca  importancia_mesma_religiao formao  \
# 0                     2.0                         4.0   b'Law'
# ...

# %%
speeddating.tail()
# Out:
#        genero  idade  idade_parceiro                            raa  \
# 8373  b'male'   25.0            26.0  b'European/Caucasian-American'
# 8374  b'male'   25.0            24.0  b'European/Caucasian-American'
# 8375  b'male'   25.0            29.0  b'European/Caucasian-American'
# 8376  b'male'   25.0            22.0  b'European/Caucasian-American'
# 8377  b'male'   25.0            22.0  b'European/Caucasian-American'
#
#                                  raa_parceiro Mesma raa?  \
# 8373               b'Latino/Hispanic American'        b'0'
# 8374                                  b'Other'        b'0'
# 8375               b'Latino/Hispanic American'        b'0'
# 8376  b'Asian/Pacific Islander/Asian-American'        b'0'
# 8377  b'Asian/Pacific Islander/Asian-American'        b'0'
#
#       importancia_mesma_raca  importancia_mesma_religiao             formao  \
# 8373                     1.0                         1.0  b'Climate Dynamics'
# ...

# %%
speeddating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8378 entries, 0 to 8377
# Data columns (total 64 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   genero                          8378 non-null   object
#  1   idade                           8283 non-null   float64
#  2   idade_parceiro                  8274 non-null   float64
#  3   raa                            8378 non-null   object
#  4   raa_parceiro                   8378 non-null   object
#  5   Mesma raa?                     8378 non-null   object
#  6   importancia_mesma_raca          8299 non-null   float64
#  7   importancia_mesma_religiao      8299 non-null   float64
#  8   formao                        8378 non-null   object
#  9   pref_parceiro_atratividade      8289 non-null   float64
#  10  pref_parceiro_sinceridade       8289 non-null   float64
#  11  pref_parceiro_inteligencia      8289 non-null   float64
# ...

# %%
speeddating.describe()
# Out:
#              idade  idade_parceiro  importancia_mesma_raca  \
# count  8283.000000     8274.000000             8299.000000
# mean     26.358928       26.364999                3.784793
# std       3.566763        3.563648                2.845708
# min      18.000000       18.000000                0.000000
# 25%      24.000000       24.000000                1.000000
# 50%      26.000000       26.000000                3.000000
# 75%      28.000000       28.000000                6.000000
# max      55.000000       55.000000               10.000000
#
#        importancia_mesma_religiao  pref_parceiro_atratividade  \
# count                 8299.000000                 8289.000000
# mean                     3.651645                   22.495347
# std                      2.805237                   12.569802
# min                      1.000000                    0.000000
# 25%                      1.000000                   15.000000
# ...

# %%
speeddating = speeddating.rename(
    columns = {
        'raa': 'raca',
        'raa_parceiro': 'raca_parceiro',
        'Mesma raa?': 'mesma_raca',
        'formao': 'formacao',
    }
)

# %%
speeddating['mesma_raca'].head()
# Out:
# 0    b'0'
# 1    b'0'
# 2    b'1'
# 3    b'0'
# 4    b'0'
# Name: mesma_raca, dtype: object

# %%
speeddating[speeddating['match']=='sim'].tail()
# Out:
#        genero  idade  idade_parceiro                            raca  \
# 8357  b'male'   25.0            26.0  b'European/Caucasian-American'
# 8360  b'male'   25.0            23.0  b'European/Caucasian-American'
# 8362  b'male'   25.0            23.0  b'European/Caucasian-American'
# 8363  b'male'   25.0            27.0  b'European/Caucasian-American'
# 8371  b'male'   25.0            25.0  b'European/Caucasian-American'
#
#                                  raca_parceiro mesma_raca  \
# 8357               b'Latino/Hispanic American'       b'0'
# 8360            b'European/Caucasian-American'       b'1'
# 8362            b'European/Caucasian-American'       b'1'
# 8363  b'Asian/Pacific Islander/Asian-American'       b'0'
# 8371  b'Asian/Pacific Islander/Asian-American'       b'0'
#
#       importancia_mesma_raca  importancia_mesma_religiao             formacao  \
# 8357                     1.0                         1.0  b'Climate Dynamics'
# ...

# %%
speeddating[speeddating['match']=='sim'].head()
# Out:
#        genero  idade  idade_parceiro  \
# 2   b'female'   21.0            22.0
# 3   b'female'   21.0            23.0
# 4   b'female'   21.0            24.0
# 8   b'female'   21.0            28.0
# 13  b'female'   24.0            23.0
#
#                                         raca  \
# 2   b'Asian/Pacific Islander/Asian-American'
# 3   b'Asian/Pacific Islander/Asian-American'
# 4   b'Asian/Pacific Islander/Asian-American'
# 8   b'Asian/Pacific Islander/Asian-American'
# 13            b'European/Caucasian-American'
#
#                                raca_parceiro mesma_raca  \
# 2   b'Asian/Pacific Islander/Asian-American'       b'1'
# 3             b'European/Caucasian-American'       b'0'
# 4                b'Latino/Hispanic American'       b'0'
# 8             b'European/Caucasian-American'       b'0'
# 13            b'European/Caucasian-American'       b'1'
#
#     importancia_mesma_raca  importancia_mesma_religiao formacao  \
# ...

# %%
speeddating = speeddating.fillna(0)

# %%
speeddating.dtypes
# Out:
# genero                         object
# idade                         float64
# idade_parceiro                float64
# raca                           object
# raca_parceiro                  object
#                                ...
# parceiro_gostou_demim_acho    float64
# conhecia_parceiro             float64
# decisao                        object
# decisao_parceiro               object
# match                          object
# Length: 64, dtype: object

# %%
speeddating[['pref_parceiro_engracado']].boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,10))
g1 = sns.pointplot(x='idade', y='pref_parceiro_atratividade', 
                   data=speeddating)
g1.set_xticklabels(g1.get_xticklabels(),rotation=90)
g1.set_title("Idade Pessoa Entrevistada e Importancia de Atratividade", fontsize=15)
g1.set_xlabel("Idade Pessoa Entrevistada")
g1.set_ylabel("Atratividade", fontsize=12)
plt.show()

# %% [markdown]
# missing_values = numeric_features.isnull().sum(axis=0).reset_index()
# missing_values.columns = ['column_name', 'missing_count']
# missing_values = missing_values.loc[missing_values['missing_count']>0]
# missing_values = missing_values.sort_values(by='missing_count')
#
# ind = np.arange(missing_values.shape[0])
# width = 0.1
# fig, ax = plt.subplots(figsize=(12,3))
# rects = ax.barh(ind, missing_values.missing_count.values, color='g')
# ax.set_yticks(ind)
# ax.set_yticklabels(missing_values.column_name.values, rotation='horizontal')
# ax.set_xlabel('Quantos faltam')
# ax.set_title('Quantos faltam - numéricos')
# plt.show()
#
#
# hosp = pd.get_dummies(hosp, columns=['vdate', 'rcount', 'gender', 'dialysisrenalendstage', 'asthma', 'irondef', 'pneum', 'substancedependence', 'psychologicaldisordermajor', 'depress', 'psychother', 'fibrosisandother', 'malnutrition', 'hemo', 'discharged'])
#
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# hosp['sodium'] = hosp['sodium'].astype(float)
# hosp[['neutrophils', 'sodium']] = scaler.fit_transform(hosp[['neutrophils', 'sodium']])
#
#
#
# numeric_features = df.select_dtypes(include=[np.number])
# numeric_features
#
#
# # Colocar mean
# #df['petal_width'] = df['petal_width'].fillna((df['petal_width'].mean()))
#
# # Colocar mediana
# #df['petal_width'] = df['petal_width'].fillna((df['petal_width'].median()))
#
# # Colocar modo
# df['petal_width'] = df['petal_width'].fillna((df['petal_width'].mode()))
# df
#
# import pandas as pd
# from pandas_profiling import ProfileReport
#
# #EDA com pandas-profiling
# profile = ProfileReport(pd.read_csv('/Users/anamees/Desktop/IRIS.csv'), explorative=True)
# profile
#
#
# #!pip3 install sweetviz
#
#
# import sweetviz as sv
#
# #EDA com Autoviz
# sweet_report = sv.analyze(pd.read_csv('/Users/anamees/Desktop/IRIS.csv'))
#
# sweet_report.show_notebook()
#
#
# df['match'] = df['match'].replace(["b'1'"], 'sim')
# df['match'] = df['match'].replace(["b'0'"], 'nao')
# df.dtypes

# %%
speeddating['genero'] = speeddating['genero'].str.replace("b", "")
speeddating['genero'] = speeddating['genero'].str.replace("'", "")

speeddating['raca'] = speeddating['raca'].str.replace("b", "")
speeddating['raca'] = speeddating['raca'].str.replace("'", "")

speeddating['raca_parceiro'] = speeddating['raca_parceiro'].str.replace("b", "")
speeddating['raca_parceiro'] = speeddating['raca_parceiro'].str.replace("'", "")

speeddating['mesma_raca'] = speeddating['mesma_raca'].str.replace("b", "")
speeddating['mesma_raca'] = speeddating['mesma_raca'].str.replace("'", "")

speeddating['formacao'] = speeddating['formacao'].str.replace("b", "")
speeddating['formacao'] = speeddating['formacao'].str.replace("'", "")

speeddating['decisao'] = speeddating['decisao'].str.replace("b", "")
speeddating['decisao'] = speeddating['decisao'].str.replace("'", "")

# %%
speeddating
# Out:
#       genero  idade  idade_parceiro                                   raca  \
# 0     female   21.0            27.0  Asian/Pacific Islander/Asian-American
# 1     female   21.0            22.0  Asian/Pacific Islander/Asian-American
# 2     female   21.0            22.0  Asian/Pacific Islander/Asian-American
# 3     female   21.0            23.0  Asian/Pacific Islander/Asian-American
# 4     female   21.0            24.0  Asian/Pacific Islander/Asian-American
# ...      ...    ...             ...                                    ...
# 8373    male   25.0            26.0            European/Caucasian-American
# 8374    male   25.0            24.0            European/Caucasian-American
# 8375    male   25.0            29.0            European/Caucasian-American
# 8376    male   25.0            22.0            European/Caucasian-American
# 8377    male   25.0            22.0            European/Caucasian-American
#
#                               raca_parceiro mesma_raca  \
# ...

# %%
def remover(lista, caracter):
    return [item.replace(caracter, '') for item in lista]

caracter = "'"
speeddating['decisao_parceiro'] = speeddating['decisao_parceiro'].apply(remover, caracter=caracter)

# %%
caracter = "b"
speeddating['decisao_parceiro'] = speeddating['decisao_parceiro'].apply(remover, caracter=caracter)

# %%
caracter = ","
speeddating['decisao_parceiro'] = speeddating['decisao_parceiro'].apply(remover, caracter=caracter)
